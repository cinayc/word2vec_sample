# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# vocabulary_size = len(vocabulary)


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
print('--- batch ---')
print(batch)
print('--- label ---')
print(labels)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# --- batch ---
# [3081 3081   12   12    6    6  195  195]
# --- label ---
# [[  12]
#  [5234]
#  [3081]
#  [   6]
#  [ 195]
#  [  12]
#  [   2]
#  [   6]]
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/gpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  # optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  281.429260254
# Nearest to they: surrogate, danneskj, australia, randomized, conciliator, bernardo, desmond, cents,
# Nearest to to: hernia, senescence, discounted, mendelian, sculptures, gigabit, incompressible, markka,
# Nearest to known: spandau, techstep, incentive, supple, rabbah, undetectable, evangelical, lighthearted,
# Nearest to he: disputes, aonb, punic, distributist, alistair, cornelis, forgave, registrar,
# Nearest to some: sqrt, incriminating, dated, alejandro, improperly, crypt, serling, ignition,
# Nearest to three: unsuccessfully, greens, mountains, reappear, tangential, disruptive, afterwards, allocated,
# Nearest to was: gangetic, ratifying, dab, clairvaux, enchanter, emirate, recited, unsubstantiated,
# Nearest to is: emulation, homeopathic, frescoes, kohlrabi, constants, cooperatively, embassies, rasterization,
# Nearest to other: prospective, glans, predecessor, foal, monmouthshire, ageing, sin, dickens,
# Nearest to which: blackmail, wie, johanna, guericke, parting, lorraine, hogs, btr,
# Nearest to UNK: glasses, teller, polycarbonate, autocorrelation, contorted, answers, concealed, politician,
# Nearest to called: genovese, trisomy, earlier, distant, failures, gotham, basie, linnean,
# Nearest to b: unofficially, neg, bugatti, fuhito, soft, khaganate, autoimmune, epitome,
# Nearest to and: endl, conceal, guys, stewed, aldebaran, customarily, interrogation, demarco,
# Nearest to no: leeuwenhoek, delgado, mentions, sacra, guilty, accelerator, imagining, brokers,
# Nearest to time: knowing, cemented, sacramental, updates, protea, bru, vertebrates, sequencing,
# Average loss at step  2000 :  113.708539145
# Average loss at step  4000 :  52.3943210196
# Average loss at step  6000 :  33.3580607326
# Average loss at step  8000 :  23.5933348026
# Average loss at step  10000 :  18.0456193917
# Nearest to they: australia, there, kyu, department, administration, lineman, surrogate, turkic,
# Nearest to to: and, in, for, ditko, or, election, markov, mythology,
# Nearest to known: spandau, rabbah, gland, department, arkham, allies, evangelical, hooker,
# Nearest to he: lymphoma, and, expenditures, fleshy, wilde, poet, disputes, they,
# Nearest to some: sqrt, danube, ignition, hakama, incriminating, were, the, uae,
# Nearest to three: one, six, five, nine, zero, eight, mountains, two,
# Nearest to was: is, were, in, monsieur, and, assessment, absent, abugida,
# Nearest to is: was, in, are, at, coke, and, snake, for,
# Nearest to other: having, predecessor, referring, carbonate, sin, overwhelmingly, acidic, numerous,
# Nearest to which: and, coke, johanna, antimatter, text, kills, deep, judge,
# Nearest to UNK: bckgr, and, one, the, zero, coke, archie, solf,
# Nearest to called: earlier, genovese, UNK, gives, connection, failures, distant, criminal,
# Nearest to b: mya, government, bugatti, amsterdam, tai, antecedent, influence, happen,
# Nearest to and: in, of, UNK, or, with, one, on, coke,
# Nearest to no: guilty, mentions, it, and, balkan, archie, formal, bckgr,
# Nearest to time: knowing, few, cemented, vertebrates, dropped, sailed, keeping, climatic,
# Average loss at step  12000 :  13.8606299995
# Average loss at step  14000 :  11.9031437682
# Average loss at step  16000 :  9.89940934098
# Average loss at step  18000 :  8.51623517644
# Average loss at step  20000 :  8.11413435137
# Nearest to they: he, it, there, not, pelagius, lineman, never, australia,
# Nearest to to: and, for, nine, dasyprocta, cabinda, incompressible, operatorname, ditko,
# Nearest to known: dasyprocta, rabbah, incentive, arkham, spandau, evangelical, scrimmage, department,
# Nearest to he: it, they, lymphoma, and, she, fleshy, who, aquila,
# Nearest to some: the, sqrt, danube, ignition, knoxville, uae, dasyprocta, incriminating,
# Nearest to three: five, six, two, eight, nine, zero, agouti, seven,
# Nearest to was: is, were, by, and, as, in, are, has,
# Nearest to is: was, are, were, ulyanov, has, as, for, circ,
# Nearest to other: carbonate, fleece, predecessor, having, monmouthshire, sin, referring, prospective,
# Nearest to which: and, that, this, dasyprocta, agouti, operatorname, coke, it,
# Nearest to UNK: operatorname, dasyprocta, agouti, bckgr, circ, amazonas, coke, acacia,
# Nearest to called: earlier, genovese, dasyprocta, distant, UNK, failures, gives, pelagius,
# Nearest to b: d, agouti, mya, reconciled, and, questioned, tai, length,
# Nearest to and: or, of, in, operatorname, dasyprocta, agouti, zero, circ,
# Nearest to no: it, and, guilty, mentions, the, imagining, balkan, dye,
# Nearest to time: cemented, knowing, few, dasyprocta, sailed, sequencing, perpetual, vertebrates,
# Average loss at step  22000 :  6.95101333463
# Average loss at step  24000 :  6.95796216822
# Average loss at step  26000 :  6.64167253006
# Average loss at step  28000 :  6.4324671241
# Average loss at step  30000 :  5.92693365991
# Nearest to they: he, it, there, not, never, pelagius, lineman, no,
# Nearest to to: for, would, nine, and, circ, cabinda, can, in,
# Nearest to known: used, dasyprocta, incentive, arkham, rabbah, scrimmage, spandau, evangelical,
# Nearest to he: it, they, she, lymphoma, who, never, and, zero,
# Nearest to some: sqrt, danube, the, wideawake, many, uae, ignition, hakama,
# Nearest to three: four, five, six, two, eight, seven, nine, zero,
# Nearest to was: is, were, has, by, had, are, been, as,
# Nearest to is: was, are, has, were, circ, ulyanov, for, as,
# Nearest to other: carbonate, hamas, fleece, monmouthshire, sin, referring, predecessor, having,
# Nearest to which: that, and, this, it, dasyprocta, agouti, one, operatorname,
# Nearest to UNK: operatorname, dasyprocta, aba, agouti, otimes, two, bckgr, amazonas,
# Nearest to called: earlier, UNK, genovese, dasyprocta, distant, failures, pompey, gives,
# Nearest to b: d, agouti, trinomial, questioned, mya, reconciled, hysteria, howitzers,
# Nearest to and: or, in, operatorname, agouti, of, dasyprocta, zero, one,
# Nearest to no: it, guilty, imagining, mentions, they, and, aleut, dye,
# Nearest to time: cemented, vendetta, knowing, few, vertebrates, perpetual, dasyprocta, sailed,
# Average loss at step  32000 :  5.93448708868
# Average loss at step  34000 :  5.71544089425
# Average loss at step  36000 :  5.78608229232
# Average loss at step  38000 :  5.50319916666
# Average loss at step  40000 :  5.23846668911
# Nearest to they: he, there, it, not, never, who, you, lineman,
# Nearest to to: for, cabinda, dasyprocta, zero, operatorname, would, nine, circ,
# Nearest to known: used, incentive, rabbah, arkham, dasyprocta, having, scrimmage, magicians,
# Nearest to he: it, they, she, who, lymphoma, never, there, zero,
# Nearest to some: many, these, wideawake, dasyprocta, hakama, uae, the, sqrt,
# Nearest to three: four, five, six, eight, seven, two, one, zero,
# Nearest to was: is, were, has, had, by, been, are, be,
# Nearest to is: was, are, has, were, be, operatorname, circ, gollancz,
# Nearest to other: hamas, carbonate, monmouthshire, two, predecessor, fleece, dasyprocta, sin,
# Nearest to which: that, this, and, it, also, dasyprocta, but, agouti,
# Nearest to UNK: operatorname, dasyprocta, agouti, aba, three, four, otimes, zero,
# Nearest to called: earlier, UNK, and, pompey, dasyprocta, genovese, failures, pelagius,
# Nearest to b: d, agouti, eight, trinomial, hysteria, zero, howitzers, mya,
# Nearest to and: or, in, dasyprocta, operatorname, zero, agouti, circ, airshow,
# Nearest to no: it, imagining, a, guilty, mentions, what, grantley, aleut,
# Nearest to time: cemented, vertebrates, perpetual, vendetta, dasyprocta, few, sailed, knowing,
# Average loss at step  42000 :  5.35724365616
# Average loss at step  44000 :  5.24024764621
# Average loss at step  46000 :  5.2215999192
# Average loss at step  48000 :  5.25142008519
# Average loss at step  50000 :  5.00368519449
# Nearest to they: he, there, it, not, you, never, who, we,
# Nearest to to: can, nine, would, for, markov, and, dasyprocta, circ,
# Nearest to known: used, incentive, rabbah, appropriating, such, it, geared, scrimmage,
# Nearest to he: it, they, she, who, never, lymphoma, there, i,
# Nearest to some: many, these, several, the, wideawake, uae, dasyprocta, their,
# Nearest to three: four, six, five, seven, two, eight, agouti, one,
# Nearest to was: is, were, has, had, by, been, be, became,
# Nearest to is: was, are, has, were, be, eight, circ, basins,
# Nearest to other: many, carbonate, hamas, some, these, two, monmouthshire, several,
# Nearest to which: that, this, it, and, also, dasyprocta, one, but,
# Nearest to UNK: operatorname, dasyprocta, agouti, aba, otimes, kapoor, five, four,
# Nearest to called: UNK, gotham, pompey, dasyprocta, earlier, prairie, failures, and,
# Nearest to b: d, agouti, hysteria, trinomial, operatorname, howitzers, seven, contingency,
# Nearest to and: or, dasyprocta, but, two, four, operatorname, agouti, kapoor,
# Nearest to no: it, imagining, or, what, aleut, summarised, accelerator, and,
# Nearest to time: cemented, vertebrates, perpetual, few, sailed, dasyprocta, kapoor, characterised,
# Average loss at step  52000 :  5.05222936022
# Average loss at step  54000 :  5.17816846919
# Average loss at step  56000 :  5.07714134252
# Average loss at step  58000 :  5.05963385129
# Average loss at step  60000 :  4.94324205047
# Nearest to they: he, there, it, you, who, we, not, never,
# Nearest to to: would, for, can, nine, will, circ, dasyprocta, not,
# Nearest to known: used, incentive, such, it, appropriating, geared, rabbah, arkham,
# Nearest to he: it, she, they, who, never, there, lymphoma, goodness,
# Nearest to some: many, these, several, the, most, two, all, other,
# Nearest to three: four, five, two, six, seven, eight, agouti, one,
# Nearest to was: is, were, has, had, by, been, became, be,
# Nearest to is: was, are, has, michelob, circ, operatorname, eight, gollancz,
# Nearest to other: many, ursus, these, some, several, two, carbonate, dasyprocta,
# Nearest to which: that, this, it, but, also, and, dasyprocta, one,
# Nearest to UNK: operatorname, ursus, agouti, dasyprocta, pulau, aba, michelob, otimes,
# Nearest to called: gotham, genovese, pompey, UNK, failures, prairie, dasyprocta, earlier,
# Nearest to b: d, agouti, hysteria, howitzers, seven, trinomial, contingency, subtrees,
# Nearest to and: or, ursus, operatorname, in, but, kapoor, agouti, dasyprocta,
# Nearest to no: it, imagining, aleut, what, summarised, dye, accelerator, amalthea,
# Nearest to time: cemented, vertebrates, dasyprocta, perpetual, few, kapoor, ursus, tin,
# Average loss at step  62000 :  5.03523518646
# Average loss at step  64000 :  4.84148324013
# Average loss at step  66000 :  4.58417369521
# Average loss at step  68000 :  5.0086153481
# Average loss at step  70000 :  4.89120970297
# Nearest to they: he, there, it, you, we, not, who, never,
# Nearest to to: would, will, can, for, not, circ, eno, dasyprocta,
# Nearest to known: used, incentive, such, appropriating, geared, rabbah, dasyprocta, ulyanov,
# Nearest to he: it, she, they, who, never, there, later, lymphoma,
# Nearest to some: many, these, several, all, other, their, most, the,
# Nearest to three: six, four, five, two, seven, eight, nine, agouti,
# Nearest to was: is, were, had, has, thaler, by, been, became,
# Nearest to is: was, are, has, does, michelob, operatorname, circ, gollancz,
# Nearest to other: many, some, several, ursus, these, various, dasyprocta, carbonate,
# Nearest to which: that, this, but, it, also, one, and, kapoor,
# Nearest to UNK: operatorname, callithrix, dasyprocta, mitral, agouti, microcebus, pulau, seven,
# Nearest to called: gotham, genovese, pompey, failures, cebus, prairie, uneasy, dasyprocta,
# Nearest to b: d, seven, agouti, UNK, mitral, hysteria, operatorname, trinomial,
# Nearest to and: or, but, kapoor, microcebus, agouti, cebus, upanija, dasyprocta,
# Nearest to no: imagining, it, any, aleut, hideous, dye, callithrix, what,
# Nearest to time: cemented, vertebrates, perpetual, difference, sailed, few, dasyprocta, way,
# Average loss at step  72000 :  4.75661725879
# Average loss at step  74000 :  4.80865993202
# Average loss at step  76000 :  4.7304219259
# Average loss at step  78000 :  4.80336151123
# Average loss at step  80000 :  4.78425626099
# Nearest to they: he, there, it, you, we, who, not, never,
# Nearest to to: dasyprocta, will, would, circ, operatorname, cabinda, nine, for,
# Nearest to known: used, such, incentive, geared, appropriating, rabbah, ulyanov, magicians,
# Nearest to he: it, she, they, who, there, never, eventually, later,
# Nearest to some: many, these, several, all, most, various, other, their,
# Nearest to three: four, six, two, five, seven, eight, agouti, one,
# Nearest to was: is, were, had, has, by, been, thaler, became,
# Nearest to is: was, has, are, does, michelob, iit, circ, airbus,
# Nearest to other: many, some, ursus, several, various, these, different, including,
# Nearest to which: that, this, it, but, also, and, kapoor, gb,
# Nearest to UNK: callithrix, operatorname, aba, agouti, microcebus, dasyprocta, ursus, pulau,
# Nearest to called: trisomy, pompey, cebus, uneasy, eighteenth, dasyprocta, gotham, failures,
# Nearest to b: d, agouti, UNK, seven, mitral, hysteria, iit, operatorname,
# Nearest to and: or, kapoor, but, dasyprocta, agouti, in, ursus, cebus,
# Nearest to no: it, escuela, imagining, any, aleut, hideous, summarised, some,
# Nearest to time: cemented, vertebrates, dasyprocta, kapoor, perpetual, difference, tin, ursus,
# Average loss at step  82000 :  4.77626411521
# Average loss at step  84000 :  4.7453720516
# Average loss at step  86000 :  4.76277178288
# Average loss at step  88000 :  4.75120856476
# Average loss at step  90000 :  4.74022938585
# Nearest to they: he, there, we, you, it, who, not, she,
# Nearest to to: would, will, cabinda, dasyprocta, circ, operatorname, markov, should,
# Nearest to known: used, such, incentive, geared, appropriating, rabbah, ulyanov, mentioned,
# Nearest to he: it, she, they, who, there, never, eventually, later,
# Nearest to some: many, these, several, all, the, various, most, other,
# Nearest to three: four, two, five, six, seven, eight, one, agouti,
# Nearest to was: is, has, were, had, been, thaler, by, became,
# Nearest to is: was, has, are, does, michelob, thaler, circ, gollancz,
# Nearest to other: several, many, ursus, some, various, different, including, these,
# Nearest to which: that, this, but, it, also, kapoor, and, these,
# Nearest to UNK: callithrix, agouti, operatorname, dasyprocta, microcebus, pulau, aba, ursus,
# Nearest to called: UNK, trisomy, used, uneasy, cebus, pompey, dasyprocta, agouti,
# Nearest to b: d, agouti, six, UNK, mitral, hysteria, iit, seven,
# Nearest to and: or, but, in, dasyprocta, kapoor, cebus, upanija, microcebus,
# Nearest to no: escuela, it, any, imagining, aleut, hideous, callithrix, a,
# Nearest to time: cemented, vertebrates, took, perpetual, way, difference, sailed, dasyprocta,
# Average loss at step  92000 :  4.65188359952
# Average loss at step  94000 :  4.72254167533
# Average loss at step  96000 :  4.69754777658
# Average loss at step  98000 :  4.58687468922
# Average loss at step  100000 :  4.70135867047
# Nearest to they: he, there, we, you, it, she, who, not,
# Nearest to to: would, circ, dasyprocta, will, microcebus, markov, operatorname, cabinda,
# Nearest to known: used, such, incentive, geared, mentioned, appropriating, rabbah, ulyanov,
# Nearest to he: it, she, they, there, who, never, dmd, later,
# Nearest to some: many, these, several, all, various, the, any, their,
# Nearest to three: four, five, six, two, seven, eight, nine, agouti,
# Nearest to was: is, has, had, were, became, been, thaler, by,
# Nearest to is: was, has, are, does, thaler, michelob, beaked, globemaster,
# Nearest to other: various, several, many, ursus, some, different, including, dasyprocta,
# Nearest to which: that, this, but, also, it, and, kapoor, however,
# Nearest to UNK: operatorname, callithrix, mitral, aba, agouti, dasyprocta, pulau, otimes,
# Nearest to called: used, trisomy, uneasy, and, cebus, pompey, apparition, imprecise,
# Nearest to b: d, dmd, agouti, mitral, hysteria, trinomial, pulau, iit,
# Nearest to and: or, but, microcebus, trinomial, kapoor, upanija, agouti, while,
# Nearest to no: any, escuela, it, stenella, imagining, aleut, callithrix, scanned,
# Nearest to time: vertebrates, cemented, way, perpetual, constituci, kapoor, took, dasyprocta,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
